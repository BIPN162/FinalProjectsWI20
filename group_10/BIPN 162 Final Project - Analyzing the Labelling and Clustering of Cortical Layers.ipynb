# %% [markdown]
# # Analyzing the Labelling and Clustering of Cortical Layers

# %% [markdown]
# # Team Member Names & Contributions
#
# Group 10

# %% [markdown]
# # Abstract

# %% [markdown]
# In our experiment, we demonstrated the differential labelling of multiple Cre-lines in the cortical layers of the primary visual cortex, and how the electrophysiological features of the cells may cluster by cortical layer. We first compared the cortical labelling of the shared Cre-lines of the Cell Types and Brain Observatory database, and found a strong positive correlation between the recorded depth metrics. We further interrogated the overlapping Cre-lines and their electrophysiology features via principal component analysis (PCA) to determine any significant clustering of cell types in the primary visual cortex using layers, cortical depth, and imaging depth. We found there to be no significant clustering of the electrophysiological characteristics by the layers of the visual cortex, but we did find that data points from Layer 4 tended to cluster closer together.

# %% [markdown]
# # Research Questions

# %% [markdown]
# 1. Do the shared Cre lines between the Allen Brain Institute Cell Types and Brain Observatory databases label the same layers in the primary visual cortex?
#
#
# 2. Do the six different layers cluster by the various cell features provided by the Cell Types or Brain Observatory databases?

# %% [markdown]
# # Background and Prior Work

# %% [markdown]
# ### Background
# In our project, we investigate the relationship between the labelling of various Cre-lines and cortical depth in the mouse cortex. The cortex is divided into six different layers, and each cortical area of the brain contains all six layers. Past experiments have established layer 4 as the input layer and layer 5 as the output layer (Cajal, 1899). These specific layers are known to have different physiological, morphological, and electrophysiological characteristics (Senzai, 2019). Layer 4 cells in the visual cortex are largely pyramidal neurons and Martinotti cell interneurons which have excitatory properties (Scala, 2019).
#
#
# The Cre-lines our project focuses on are Sst-IRES-Cre, Pvalb-IRES-Cre, Vip-IRES-Cre, Cux2-CreERT2, Nr5a1-Cre, Ntsr1-Cre_GN220, Rbp4-Cre_KL100, Rorb-IRES-Cre, Scnn1a-Tg3-Cre, and Tlx3-Cre_PL56. Each of the Cre-lines are defined by the expression of their specific genes and are variably expressed in neurons throughout the brain. These Cre-lines are created through the Cre/Lox system that functions by crossing Cre-recombinase expressing driver mice with the LoxP sites specifically indicating the cells with the gene of interest. These mouse lines can also be crossed with fluorescent reporter mice to selectively label cells of interest that are expressing Cre and the gene of interest.
#
#
# It is useful to define the depth and location of the cells labeled by each Cre-line, in addition to the characteristics of their gene expression patterns, to distinguish gene localization for future manipulation and Cre-line candidates. There is abundant literature on utilizing these tissue specific Cre-lines to determine the electrophysiological properties and neurotransmitter specific excitability of neurons expressing these genes (Sundberg, 2017). Our findings showed discrepancies in the cortical depth metrics of the Allen Brain Institute's databases when compared to the existing experimental literature as well as some correlation between these metrics. This led us to examine if the shared Cre-lines from the Allen Brain Institute Cell Types and Brain Observatory databases label the same layers in the mouse primary visual cortex and if these layers cluster based on cell features provided by these databases.
#
#
# We are investigating the relationship between cell type, electrophysiological properties, and circuit structure with clustering analysis through principal component analysis (PCA). This tool allows us to breakdown complex signals and analog recordings into programmatically manageable chunks of digital data. These chunks are analyzed with orthogonal components with decreasing variability to determine whether or not these points cluster in such a way that suggests their proximity based on variability. In our experiment we performed PCA on the overlapping Cre-lines based on the normalized depth metric and the imaging depth to determine if the cell types cluster according to cortical layers.

# %% [markdown]
# ### Cell Types Database Description
# Our first database, the Allen Brain Institute Cell Types database, includes the morphology and electrophysiology data of various cells targeted with specific Cre-lines. The database includes the brain region and the Cre-line that targeted a subset of neurons. The experimenters recorded from different cells by using the Cre/LoxP system to express GFP in the cells specific to the Cre-line. The experimenters then injected various currents into the cells and collected data on many internal electrophysiological properties of the cell. We will utilize the normalized depth metric in this database to graph a boxplot for the recordings of each Cre-line, to compare the depth of expression between these Cre-lines. After filtering the data for each Cre-line, our dataset resulted in 937 observations. We will also use the electrophysiology data which contains numerous features, including the resting membrane potential and adaptation rate of each cell. With this data, we can perform PCA analysis to determine if the electrophysiology features of the cells cluster by their cortical layer.

# %% [markdown]
# ### Brain Observatory Database Description
# Our second database, the Allen Brain Institute's Brain Observatory, includes calcium imaging from GCaMP6 experiments on various cell types in the visual cortex. These experiments are divided by the cell type and Cre-line. The database  includes the data recorded from the calcium imaging experiments where mice were shown various visual stimuli, such as  the orientation and direction selectivity of the cells. The Brain Observatory database also includes a normalized depth metric which distinguishes the Cre-line of the recorded cells. After filtering the data for each Cre-line, the number of observations totalled to 110 experiments.  We will use this data for our PCA analysis to determine if these features also cluster by layer.

# %% [markdown]
# ### References (include links):
# (1) Cajal Santiago Ramón y. (1899). Textura del sistema nervioso del hombre y de los vertebrados. Madrid: Impr. y Libr. de Nicolás Moya.
#
# (2) Scala, F., Kobak, D., Shan, S. et al. (2019). Layer 4 of mouse neocortex differs in cell types and circuit organization between sensory areas. Nat Commuun 10, 4174. https://doi.org/10.1038/s41467-019-12058-z
#
# (3) Senzai, Y., Fernandez-Ruiz, A., Buzsaki, G. (2019). Layer-Specific Physiological Features and Interlaminar Interactions in the Primary Visual Cortex of the Mouse. Neuron 101, 500-513. https://www.cell.com/neuron/pdf/S0896-6273(18)31085-7.pdf
#
# (3) Sundberg, Sofie Charlotte, et al. (2017). “Cre-Expressing Neurons in Visual Cortex of Ntsr1-Cre GN220 Mice Are Corticothalamic and Are Depolarized by Acetylcholine.” Journal of Comparative Neurology, vol. 526, no. 1, pp. 120–132., doi:10.1002/cne.24323

# %% [markdown]
# # Hypothesis

# %% [markdown]
# 1. We hypothesize each Cre-line shared between the two databases, the Allen Brain Cell Types and Brain Observatory, will label a specific cortical layer in the primary visual cortex.
#
#     1. Since the labelling of the Cre-lines have already been characterized, we believe the results of our cortical depth should compare to the layers defined in the literature.
#     2. Also based on the literature, there should be a few Cre-lines that are not specific to a cortical layer, and instead consist of scattered expression throughout the cortex.
#
#
# 2. We hypothesize the data will not cluster into six distinct clusters for each layer, but we do predict the data for Layer 4 will cluster together.
#
#     1. Layer 4 exists as a distinct layer, compared to the other layers of cortex, because it is the primary input layer to cortex. Therefore, we believe the distinct cell features of this layer will cause the data for Layer 4 to cluster closer together.

# %% [markdown]
# # Setup

# %% [markdown]
# We will import the toolboxes from allensdk and necessary packages.

# %%
# Import the necessary toolboxes from the allensdk
from allensdk.core.cell_types_cache import CellTypesCache
from allensdk.api.queries.cell_types_api import CellTypesApi

#Here I have imported any packages that I felt would be necessary to manipulate the data 
import matplotlib as mpl
import matplotlib.pyplot as plt
from random import sample 
from mpl_toolkits.mplot3d import Axes3D
from scipy import stats
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.decomposition import PCA

# %matplotlib inline

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# Our data wrangling consists of indexing and subsetting the databases, so we only analyze the Cre-lines shared between the database and only in the primary visual cortex.

# %% [markdown]
# ## Part 1: Import the Data from Both Databases

# %% [markdown]
# ### Import Cell Types Data
# We will first import the data from the Cell Types Database and specify the species as mouse. We will also import the electrophysiology features for these cells.

# %%
#We'll initialize the cache as 'ctc' (cell types cache)
ctc = CellTypesCache(manifest_file='cell_types/manifest.json')

# %%
#We are not interested in the human cells, so we will specify that we want the mouse cells
mouse_cells = ctc.get_cells(species=[CellTypesApi.MOUSE])

# %%
ephys_features = pd.DataFrame(ctc.get_ephys_features()).set_index('specimen_id')

# %% [markdown]
# We will then place the data we have collected into a pandas dataframe in order to make it easier to manipulate when wrangling our data.

# %%
#here we do pd to access the pandas class and create a dataframe with the mouse data
mouse_df = pd.DataFrame(mouse_cells)

#we can then see how our data frame looks by using the head method to display
#the first 5 rows of the df
mouse_df = mouse_df.set_index('id')
mouse_df.head()
# Out:
#           reporter_status                                 cell_soma_location  \
# id
# 565871768        positive  [8966.56330957526, 1429.52689052075, 8567.3896...
# 469801138        positive  [7872.53138541818, 993.212032389272, 3127.1530...
# 605889373        positive       [9400.0, 1520.74232706376, 2188.13845194139]
# 485909730        positive       [8881.0, 953.839501299405, 7768.22695782726]
# 323865917        positive       [8125.0, 904.841803028986, 7819.69986630448]
#
#                 species                                               name  \
# id
# 565871768  Mus musculus                   Oxtr-2A-Cre;Ai14-293837.03.01.02
# 469801138  Mus musculus                Pvalb-IRES-Cre;Ai14-170927.05.02.01
# 605889373  Mus musculus  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO;Ai65-337419.0...
# 485909730  Mus musculus                  Cux2-CreERT2;Ai14-205530.03.02.01
# 323865917  Mus musculus                Scnn1a-Tg3-Cre;Ai14-172530.06.01.01
#
# ...

# %% [markdown]
# ### Import Brain Observatory Data
# We will then import the data from the Brain Observatory Database.

# %%
import allensdk.brain_observatory.stimulus_info as stim_info
from allensdk.core.brain_observatory_cache import BrainObservatoryCache

# We will create an instance of the Brain Observatory Cache as an object, "boc."
boc = BrainObservatoryCache(manifest_file='/datasets/allen-brain-observatory/visual-coding-2p/manifest.json')

# %% [markdown]
# ## Part 2: Define the Overlapping Layers between the Databases

# %% [markdown]
# We will find the list of Cre lines in the Brain Observatory database.

# %%
# We'll save the list of cre lines as a variable, 'cre-lines'.
cre_lines = boc.get_all_cre_lines()
print("all cre lines: " + str(cre_lines))

# We'll save the list of possible structures as a variable, 'brain_areas'.
brain_areas = boc.get_all_targeted_structures()
print("all brain regions: " + str(brain_areas))
# Out:
# all cre lines: ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Fezf2-CreER', 'Nr5a1-Cre', 'Ntsr1-Cre_GN220', 'Pvalb-IRES-Cre', 'Rbp4-Cre_KL100', 'Rorb-IRES2-Cre', 'Scnn1a-Tg3-Cre', 'Slc17a7-IRES2-Cre', 'Sst-IRES-Cre', 'Tlx3-Cre_PL56', 'Vip-IRES-Cre']
# all brain regions: ['VISal', 'VISam', 'VISl', 'VISp', 'VISpm', 'VISrl']

# %% [markdown]
# We then find the list of Cre lines in the Cell Types database.

# %%
# With this code we can look at a list of the transgenic lines that exist within our cell types dataframe
#.unique filters out any replicates so it gives us one solid list of the cre-lines present
transgenic_lines = mouse_df['transgenic_line'].unique()

# %% [markdown]
# Here we are synthesizing the list of Cre-lines we are interested in, we do this by comparing the list of Cre-lines in both databases to see which ones match. We then store them in a list, labelled overlapping_lines.

# %%
#this code checks to see which lines overlap between the two list of lines from each database 
#transgenic is from the celltypes database and cre is from the boc database
overlapping_lines = list(set(transgenic_lines).intersection(cre_lines))
overlapping_lines
# Out:
# ['Pvalb-IRES-Cre',
#  'Cux2-CreERT2',
#  'Tlx3-Cre_PL56',
#  'Nr5a1-Cre',
#  'Scnn1a-Tg3-Cre',
#  'Vip-IRES-Cre',
#  'Sst-IRES-Cre',
#  'Ntsr1-Cre_GN220',
#  'Rorb-IRES2-Cre',
#  'Rbp4-Cre_KL100']

# %% [markdown]
# ## Part 3: Create Dataframes Specific to VISp and the Overlapping Cre-lines

# %% [markdown]
# ### Create a Dataframe for the Brain Observatory Data

# %% [markdown]
# We will now create a database from the Brain Observtory data with the cells specifically in the primary visual cortex and only from the Cre-lines that overlap between the two databases.

# %%
exps = boc.get_experiment_containers(targeted_structures = ['VISp'], cre_lines= overlapping_lines)
exps_df = pd.DataFrame(exps)
exps_df.head()
# Out:
#           id  imaging_depth targeted_structure         cre_line  \
# 0  511510911            350               VISp   Scnn1a-Tg3-Cre
# 1  644909309            550               VISp  Ntsr1-Cre_GN220
# 2  511510736            175               VISp     Cux2-CreERT2
# 3  528792730            350               VISp        Nr5a1-Cre
# 4  581026086            275               VISp     Sst-IRES-Cre
#
#                 reporter_line donor_name  \
# 0          Ai93(TITL-GCaMP6f)     230570
# 1  Ai148(TIT2L-GC6f-ICL-tTA2)     348105
# 2          Ai93(TITL-GCaMP6f)     222426
# 3          Ai93(TITL-GCaMP6f)     248894
# 4  Ai148(TIT2L-GC6f-ICL-tTA2)     297507
#
#                            specimen_name tags  failed
# 0  Scnn1a-Tg3-Cre;Camk2a-tTA;Ai93-230570   []   False
# 1           Ntsr1-Cre_GN220;Ai148-348105   []   False
# 2    Cux2-CreERT2;Camk2a-tTA;Ai93-222426   []   False
# 3       Nr5a1-Cre;Camk2a-tTA;Ai93-248894   []   False
# 4         Sst-IRES-Cre;Ai148(CAM)-297507   []   False

# %% [markdown]
# ### Create a Dataframe for the Cell Types data
# We will create a dataframe from the Cell Types database by indexing the original database for each of the Cre-lines specificed in the overlapping_lines list. We will also only include the VISp area in our new database.

# %%
mouse_df_exps = mouse_df.loc[(mouse_df['transgenic_line'] == overlapping_lines[0])|(mouse_df['transgenic_line'] == overlapping_lines[1])|(mouse_df['transgenic_line'] == overlapping_lines[2])|(mouse_df['transgenic_line'] == overlapping_lines[3])|(mouse_df['transgenic_line'] == overlapping_lines[4])|(mouse_df['transgenic_line'] == overlapping_lines[5])|(mouse_df['transgenic_line'] == overlapping_lines[6])|(mouse_df['transgenic_line'] == overlapping_lines[7])|(mouse_df['transgenic_line'] == overlapping_lines[8])|(mouse_df['transgenic_line'] == overlapping_lines[9])]
mouse_df_exps = mouse_df_exps.loc[(mouse_df_exps['structure_area_abbrev'] == 'VISp')]

mouse_df_exps.head()
# Out:
#           reporter_status                                 cell_soma_location  \
# id
# 469801138        positive  [7872.53138541818, 993.212032389272, 3127.1530...
# 485909730        positive       [8881.0, 953.839501299405, 7768.22695782726]
# 323865917        positive       [8125.0, 904.841803028986, 7819.69986630448]
# 504615116        positive  [9022.31795341815, 1034.01756171273, 3750.0960...
# 476135066        positive      [8711.26681152, 1417.44904628, 8895.04077315]
#
#                 species                                   name  \
# id
# 469801138  Mus musculus    Pvalb-IRES-Cre;Ai14-170927.05.02.01
# 485909730  Mus musculus      Cux2-CreERT2;Ai14-205530.03.02.01
# 323865917  Mus musculus    Scnn1a-Tg3-Cre;Ai14-172530.06.01.01
# 504615116  Mus musculus  Rorb-IRES2-Cre-D;Ai14-234241.04.02.01
# 476135066  Mus musculus    Scnn1a-Tg3-Cre;Ai14-187849.06.01.01
#
#           structure_layer_name  structure_area_id structure_area_abbrev  \
# id
# ...

# %% [markdown]
# ### Create a Dataframe with the Ephys Features of the Cell Types data
# We will join our new Cell Types dataframe with the electrophysiological features for each cell.

# %%
mouse_ephys_df = mouse_df_exps.join(ephys_features)
mouse_ephys_df.head()
# Out:
#           reporter_status                                 cell_soma_location  \
# id
# 469801138        positive  [7872.53138541818, 993.212032389272, 3127.1530...
# 485909730        positive       [8881.0, 953.839501299405, 7768.22695782726]
# 323865917        positive       [8125.0, 904.841803028986, 7819.69986630448]
# 504615116        positive  [9022.31795341815, 1034.01756171273, 3750.0960...
# 476135066        positive      [8711.26681152, 1417.44904628, 8895.04077315]
#
#                 species                                   name  \
# id
# 469801138  Mus musculus    Pvalb-IRES-Cre;Ai14-170927.05.02.01
# 485909730  Mus musculus      Cux2-CreERT2;Ai14-205530.03.02.01
# 323865917  Mus musculus    Scnn1a-Tg3-Cre;Ai14-172530.06.01.01
# 504615116  Mus musculus  Rorb-IRES2-Cre-D;Ai14-234241.04.02.01
# 476135066  Mus musculus    Scnn1a-Tg3-Cre;Ai14-187849.06.01.01
#
#           structure_layer_name  structure_area_id structure_area_abbrev  \
# id
# ...

# %% [markdown]
# ## Part 3: Preparing Both Dataframes for  PCA Analysis

# %% [markdown]
# We will subset the Cell Types data to only include numeric values. We are indicating the data type that we will accept, so that strings are not included in the dataframe.

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
ephys_subset = mouse_ephys_df.select_dtypes(include=numerics)
#here we are dropping any NA's from our df
ephys_subset = ephys_subset.dropna(axis=0).dropna(axis=1)
ephys_subset.head()
# Out:
#            structure_area_id   donor_id  normalized_depth  adaptation  \
# id
# 485909730                385  485250100          0.478344    0.032340
# 323865917                385  322489588          0.608590    0.026732
# 504615116                385  503871551          0.684800    0.014800
# 476135066                385  475849748          0.419116    0.098665
# 480087928                385  479695183          0.446400    0.018392
#
#               avg_isi  electrode_0_pa  f_i_curve_slope  \
# id
# 485909730   55.895000      -55.964379         0.250000
# 323865917   94.233500       96.421870         0.164286
# 504615116   92.074000       43.207500         0.177671
# 476135066  113.287143      -68.804996         0.139337
# 480087928   58.051667      256.913130         0.199214
#
#            fast_trough_t_long_square  fast_trough_t_ramp  \
# id
# 485909730                   1.112495            2.853377
# 323865917                   1.197855            3.423100
# ...

# %% [markdown]
# We will now  drop the meaningless columns and normalize the data.

# %%
#Here we have to drop the meaningless columns
ephys_norm = ephys_subset.drop(columns = ['structure_area_id', 'donor_id'])
ephys_norm.head()
# Out:
#            normalized_depth  adaptation     avg_isi  electrode_0_pa  \
# id
# 485909730          0.478344    0.032340   55.895000      -55.964379
# 323865917          0.608590    0.026732   94.233500       96.421870
# 504615116          0.684800    0.014800   92.074000       43.207500
# 476135066          0.419116    0.098665  113.287143      -68.804996
# 480087928          0.446400    0.018392   58.051667      256.913130
#
#            f_i_curve_slope  fast_trough_t_long_square  fast_trough_t_ramp  \
# id
# 485909730         0.250000                   1.112495            2.853377
# 323865917         0.164286                   1.197855            3.423100
# 504615116         0.177671                   1.181160            3.367927
# 476135066         0.139337                   1.151005            5.805325
# 480087928         0.199214                   1.821510            3.174485
#
#            fast_trough_t_short_square  fast_trough_v_long_square  \
# id
# ...

# %%
#Normalization
ephys_norm = (ephys_norm - ephys_norm.mean())/ephys_norm.std()
ephys_norm.head()
# Out:
#            normalized_depth  adaptation   avg_isi  electrode_0_pa  \
# id
# 485909730         -0.220468   -0.401013 -0.721466       -1.493225
# 323865917          0.580528   -0.469893  0.352585        2.957066
# 504615116          1.049211   -0.616449  0.292087        1.402992
# 476135066         -0.584709    0.413647  0.886372       -1.868223
# 480087928         -0.416914   -0.572329 -0.661047        7.644056
#
#            f_i_curve_slope  fast_trough_t_long_square  fast_trough_t_ramp  \
# id
# 485909730         0.501468                  -0.529264           -0.952178
# 323865917        -0.271602                   0.117349           -0.654347
# 504615116        -0.150876                  -0.009117           -0.683190
# 476135066        -0.496619                  -0.237545            0.590993
# 480087928         0.043423                   4.841617           -0.784314
#
#            fast_trough_t_short_square  fast_trough_v_long_square  \
# id
# ...

# %% [markdown]
# We are pulling the experiment containers for the specimen in our overlapping lines from BOC.

# %%
specimen_containers = list(exps_df['id'])
overlapping_specimens = pd.DataFrame(boc.get_cell_specimens(experiment_container_ids=specimen_containers))
overlapping_specimens.head()
# Out:
#    p_run_mod_sg    tlr1_id  image_sel_ns           tlr1_name  g_dsi_dg  p_ns  \
# 0           NaN  265943423           NaN  Ai93(TITL-GCaMP6f)       NaN   NaN
# 1           NaN  265943423           NaN  Ai93(TITL-GCaMP6f)  0.824858   NaN
# 2           NaN  265943423           NaN  Ai93(TITL-GCaMP6f)  0.812462   NaN
# 3           NaN  265943423           NaN  Ai93(TITL-GCaMP6f)  0.078742   NaN
# 4           NaN  265943423           NaN  Ai93(TITL-GCaMP6f)       NaN   NaN
#
#    specimen_id          p_dg  time_to_peak_sg  pref_dir_dg  ...  peak_dff_ns  \
# 0    502185555           NaN              NaN          NaN  ...          NaN
# 1    502185555  2.690800e-15              NaN          0.0  ...          NaN
# 2    502185555  3.070093e-02              NaN        180.0  ...          NaN
# 3    502185555  1.245296e-01              NaN          NaN  ...          NaN
# 4    502185555           NaN              NaN          NaN  ...          NaN
#
# ...

# %% [markdown]
# We will subset the Brain Observatory data to only contain numeric values. We are indicating the data type that we will accept, so that strings are not included in the dataframe.

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
boc_subset = overlapping_specimens.select_dtypes(include=numerics)
#here we are dropping any NA's from our df
boc_subset = boc_subset.dropna(axis=0).dropna(axis=1)
boc_subset.head()
# Out:
#       p_run_mod_sg    tlr1_id  image_sel_ns  g_dsi_dg          p_ns  \
# 294       0.297968  265943423      0.695864  0.709259  9.375502e-30
# 474       0.363559  265943423      0.389153  0.671237  1.523700e-05
# 834       0.034386  265943423      0.293271  0.318224  1.647265e-17
# 877       0.118859  265943423      0.755237  0.171018  4.352804e-81
# 1580      0.004745  265943423      0.593102  0.196935  6.545678e-11
#
#       specimen_id          p_dg  time_to_peak_sg  pref_dir_dg    dsi_dg  ...  \
# 294     491618855  3.084007e-03          0.03326          0.0  1.502792  ...
# 474     491618855  1.264892e-05          0.33260        135.0  0.563787  ...
# 834     495726993  2.453298e-12          0.29853         45.0  0.417253  ...
# 877     495726993  4.266922e-22          0.29853          0.0  0.682854  ...
# 1580    496001358  1.390580e-04          0.33170        270.0  0.277289  ...
#
#       reliability_nm1_b  rf_center_off_x_lsn  peak_dff_ns  run_mod_sg  \
# ...

# %% [markdown]
# Here we have to drop the meaningless columns and normalize the data.

# %%
#Here we have to drop the meaningless columns
boc_subset = boc_subset.drop(columns = ['specimen_id', 'tlr1_id', 'tld2_id'])

# %%
#Normalize data
boc_norm = (boc_subset - boc_subset.mean())/boc_subset.std()
boc_norm.head()
# Out:
#       p_run_mod_sg  image_sel_ns  g_dsi_dg      p_ns      p_dg  \
# 294       0.098636      0.962568  0.557509 -0.253427  0.178132
# 474       0.357690     -0.528123  0.434811 -0.187267 -0.285676
# 834      -0.942404     -0.994129 -0.704390 -0.253427 -0.287586
# 877      -0.608772      1.251134 -1.179434 -0.253427 -0.287586
# 1580     -1.059474      0.463118 -1.095799 -0.253427 -0.266587
#
#       time_to_peak_sg  pref_dir_dg    dsi_dg  rf_overlap_index_lsn  \
# 294         -3.228604    -1.262687  1.517953             -0.278614
# 474          0.810911    -0.115843 -0.483405              2.513467
# 834          0.351145    -0.880405 -0.795720             -0.605120
# 877          0.351145    -1.262687 -0.229630             -0.605120
# 1580         0.798766     1.031001 -1.094035              0.651838
#
#       rf_distance_lsn  ...  reliability_nm1_b  rf_center_off_x_lsn  \
# 294          0.003893  ...          -0.608921            -0.575363
# ...

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# ## Part 1: Create Boxplots to Analyze the Depths of the Cre-lines in each Database
#
# ### Graph a Boxplot of the Cell Types Data
# Here we will graph a boxplot for the normalized depth metric from the Cell Types database for all of our Cre-lines.

# %%
fig, ax = plt.subplots(figsize=(15,10))

ax = sns.boxplot(x = 'transgenic_line', y='normalized_depth', data=mouse_df_exps, order=['Cux2-CreERT2',
 'Ntsr1-Cre_GN220',
 'Tlx3-Cre_PL56',
 'Scnn1a-Tg3-Cre',
 'Sst-IRES-Cre',
 'Pvalb-IRES-Cre',
 'Vip-IRES-Cre',
 'Nr5a1-Cre',
 'Rbp4-Cre_KL100',
 'Rorb-IRES2-Cre'] )

plt.title("Normalized Depth of each Cre Line", fontsize = 20)
ax.set_ylim(1.0,0)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Cux2-CreERT2'),
#  Text(0, 0, 'Ntsr1-Cre_GN220'),
#  Text(0, 0, 'Tlx3-Cre_PL56'),
#  Text(0, 0, 'Scnn1a-Tg3-Cre'),
#  Text(0, 0, 'Sst-IRES-Cre'),
#  Text(0, 0, 'Pvalb-IRES-Cre'),
#  Text(0, 0, 'Vip-IRES-Cre'),
#  Text(0, 0, 'Nr5a1-Cre'),
#  Text(0, 0, 'Rbp4-Cre_KL100'),
#  Text(0, 0, 'Rorb-IRES2-Cre')]

# %% [markdown]
# ### Figure 1.
# This boxplot graphs the normalized depth of each Cre line, with the data from the Cell Types database. The bottom of the graph represents the deepest layer and the top represents the more superficial layers of cortex. The graph reveals Ntsr1-Cre labels the deepest layer of cortex, compared to the other lines. The Pvalb-IRES-Cre, Sst-IRES-Cre, Rorb-IRES2-Cre, and the Vip-IRES-Cre lines show scattered expression throughout the layers. All of the other lines vary between the middle layers of cortex.

# %% [markdown]
# ### Graph a Boxplot of the Brain Observatory Data
# We will make another boxplot for the imaging depth collected in the Brain Observatory database for each Cre line.

# %%
fig,ax = plt.subplots(figsize=(15,10))


ax = sns.boxplot(x='cre_line', y='imaging_depth', data=exps_df, order=['Cux2-CreERT2',
 'Ntsr1-Cre_GN220',
 'Tlx3-Cre_PL56',
 'Scnn1a-Tg3-Cre',
 'Sst-IRES-Cre',
 'Pvalb-IRES-Cre',
 'Vip-IRES-Cre',
 'Nr5a1-Cre',
 'Rbp4-Cre_KL100',
 'Rorb-IRES2-Cre'] )

plt.title("Imaging Depth of each Cre Line", fontsize = 20)
ax.set_ylim(600,0)


ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Cux2-CreERT2'),
#  Text(0, 0, 'Ntsr1-Cre_GN220'),
#  Text(0, 0, 'Tlx3-Cre_PL56'),
#  Text(0, 0, 'Scnn1a-Tg3-Cre'),
#  Text(0, 0, 'Sst-IRES-Cre'),
#  Text(0, 0, 'Pvalb-IRES-Cre'),
#  Text(0, 0, 'Vip-IRES-Cre'),
#  Text(0, 0, 'Nr5a1-Cre'),
#  Text(0, 0, 'Rbp4-Cre_KL100'),
#  Text(0, 0, 'Rorb-IRES2-Cre')]

# %% [markdown]
# ### Figure 2.
# This boxplot graphs the imaging depth of each Cre line, with the data from the Brain Observatory database. The bottom of the graph represents the deepest layer and the top represents the more superficial layers of cortex. The graph also reveals that Ntsr1-Cre labels the deepest layer of cortex. In this boxplot, both the Sst-IRES-Cre, Pvalb-IRES-Cre, and Vip-IRES-Cre lines demonstrate the greatest spread of expression across cortex. Interestingly, the Rorb-IRES2-Cre does not demonstrate scattered expression. Rbp4-Cre and Tlx3-Cre both show dense expression in the same layer. Scnn1a-Tg3-Cre and Nr5a1-Cre also both show expression in the same layer, which is slightly more superficial.

# %% [markdown]
# ## Part 2: Perform Correlational Analysis on the Depths between the Two Databases

# %% [markdown]
# ### Determine if the Data is Skewed
# We will now run a skewtest on the depth data provided by both databases. If the data is skewed, then we will report the median. If the data is normally distributed, then we will report the mean.

# %% [markdown]
# We will run the skew test on the Cell Types data.

# %%
ct_skewtest = mouse_df_exps['normalized_depth']

ct_skewed_stats, ct_skewed = stats.skewtest(ct_skewtest)
if ct_skewed > 0.05:
    print('Normal Distribution')
else:
    print('Skewed Distribution')
# Out:
# Skewed Distribution

# %% [markdown]
# We will then run the skew test on the Brain Observatory data.

# %%
boc_skewtest = exps_df['imaging_depth']

boc_skewed_stats, boc_skewed = stats.skewtest(boc_skewtest)
if boc_skewed > 0.05:
    print('Normal Distribution')   
else:
    print('Skewed Distribution')
# Out:
# Skewed Distribution

# %% [markdown]
# ### Determine the Median Depth for each Cre-line
# Since both datasets consist of skewed distributions, we will find the median depth for each Cre-line.

# %%
celltypes_medians = []
for line in overlapping_lines:
    med = mouse_df_exps[mouse_df_exps['transgenic_line'] == line]['normalized_depth'].median()
    celltypes_medians.append(med)

boc_medians = []
for line in overlapping_lines:
    med2 = exps_df[exps_df['cre_line'] == line]['imaging_depth'].median()
    boc_medians.append(med2)
    
print(celltypes_medians)
print(boc_medians)
# Out:
# [0.5227868586293505, 0.45185051685577005, 0.5420492258911205, 0.408190155407996, 0.46336818457228, 0.387328592630399, 0.634047119763261, 0.870134676511205, 0.49184699080218053, 0.546854367118561]
# [275.0, 225.0, 375.0, 350.0, 350.0, 175.0, 285.0, 550.0, 275.0, 375.0]

# %% [markdown]
# ### Plot the Correlation and Determine the Pearson's r
# We will now plot the medians across both databases. Since we are using an array of medians to display the correlation, we will also calculate the iterquartile range and plot the values as error bars to demonstrate the spread of our data. We had to use the subset dataframes to calculate the IQRs for each database, because these dataframes dropped all NaNs, which would cause errors when calculating the IQRs.

# %%
from scipy.stats import iqr

#calculate IQR using the IQR function 
iqr1 = iqr(ephys_subset.normalized_depth)
iqr2 = iqr(boc_subset.imaging_depth)
print(iqr1)
print(iqr2)


plt.scatter(celltypes_medians, boc_medians)
plt.title('Correlation between the Depths of Each Shared Cre-line')
plt.xlabel('Cell Types Normalized Depth')
plt.ylabel('Brain Observatory Imaging Depth')
plt.errorbar(celltypes_medians, boc_medians, yerr = iqr2, xerr = iqr1, fmt='none', ecolor = 'grey')
plt.show()
# Out:
# 0.150761170141552
# 75.0

# %% [markdown]
# ### Figure 3.
# This scatterplot reveals the positive correlation between the normalized depth of the Cell Types database and the imaging depth of the Brain Observatory database. The plot also includes error bars with the calculated IQRs each database.

# %% [markdown]
# We now calculate the Pearson's r and p-value for both datasets.

# %%
pearsons_r , pearsons_p = stats.stats.pearsonr(celltypes_medians, boc_medians)
print("pearson's r: %f    pearson's p: %f" % (pearsons_r, pearsons_p))
# Out:
# pearson's r: 0.778317    pearson's p: 0.008007

# %% [markdown]
# The Pearson's r reveals a strong, positive correlation between the depths of both databases, at .78. This is a significant correlation because the p-value is below 0.05.

# %% [markdown]
# ## Part 3: Perform PCA Analysis for the Cell Types Data
#
#
# ### Generate a Scree Plot for the Cell Types Data
# Here we are generating a Scree plot to determine the number of components we should use for the PCA analysis.

# %%
# Create a PCA model
pca = PCA()
data_pca = pca.fit_transform(ephys_norm)
#Here we plot out the data
plt.plot(pca.explained_variance_ratio_) # Plot the expected variance as a function of the PC
plt.axhline(.08,c='k',ls='--') # Plot a horizontal line at 1, the Kaiser criterion

plt.title('Scree Plot for the Cell Types Data')
plt.ylabel('Eigenvalue') 
plt.xlabel('Principal Component #')
plt.xlim(0,5)
plt.show()

# %% [markdown]
# ### Figure 4.
# Based off the elbow method for the Scree plot, we determined that we should include 4 components in our PCA analysis. We decided this by determining where our plot crosses the dotted line. We set the dotted line at 1, which is the Kaiser criterion. Since the line crosses around 3.5, we decided to include 4 components.

# %% [markdown]
# ### Perform PCA Clustering Analysis on the Cell Types Data
# We will now conduct the PCA analysis on our Cell Types Ephys Normalized data, with 4 components.

# %%
#Create PCA model
pca = PCA(n_components = 4)    
#fit data to 2d model
ephys_2D = pca.fit_transform(ephys_norm) 

ephys_subset['PC1'] = ephys_2D[:, 0]
ephys_subset['PC2'] = ephys_2D[:, 1]
ephys_subset['PC3'] = ephys_2D[:, 2]
ephys_subset['PC4'] = ephys_2D[:, 3]

ephys_subset['structure_layer_name'] = mouse_ephys_df['structure_layer_name']

sns.lmplot("PC2", "PC3", hue='structure_layer_name', data=ephys_subset, fit_reg=False)
plt.title('PC2 vs. PC3 Clustering Analysis for the Cell Types Ephys Data')
plt.show()

# %% [markdown]
# ### Figure 5.
# After running the PCA analysis on various PC combinations, we decided to graph PC2 vs. PC3. This graph best reveals the clustering of layer 4 (orange), compared to the other layers. Overall, we do not see prominent clustering of the layers based off of the electrophysiology data. We did notice that Layer 4 tended to cluster closer together.

# %% [markdown]
# ### Perform PCA Analysis for Layer 4 vs. all the Other Layers
# Since we noticed that Layer 4 tended to cluster closer together, we decided to perform a PCA analysis of Layer 4 compared to all of the other layers.

# %%
#We first have to make a separate data frame inorder to save the data without effecting our first pca plot
ephys_subset_grouped = ephys_subset

# %% [markdown]
# Here we are grouping all of the layers besides Layer 4. If the value in the layer columns consists of any layer besides Layer 4, we assign the data to  grouped_layers. If the value consists of Layer 4, then we assign the data to layer_four

# %%
ephys_subset_grouped.loc[ephys_subset.structure_layer_name == '1' , 'layer'] = 'grouped_layers'
ephys_subset_grouped.loc[ephys_subset.structure_layer_name == '2/3' , 'layer'] = 'grouped_layers'
ephys_subset_grouped.loc[ephys_subset.structure_layer_name == '5' , 'layer'] = 'grouped_layers'
ephys_subset_grouped.loc[ephys_subset.structure_layer_name == '6a' , 'layer'] = 'grouped_layers'
ephys_subset_grouped.loc[ephys_subset.structure_layer_name == '6b' , 'layer'] = 'grouped_layers'
ephys_subset_grouped.loc[ephys_subset.structure_layer_name == '4', 'layer'] = 'layer_four'

# %%
sns.lmplot("PC2", "PC3", hue='layer', data=ephys_subset_grouped, fit_reg=False)
plt.title('PC2 vs. PC3 Clustering Analysis for Layer 4')
plt.show()

# %% [markdown]
# ### Figure 6.
# Our clustering analysis reveals that Layer 4 tends to cluster closer together. But, Layer 4 does not cluster exclusively from the other layers. All of the layers are clustered into one cluster, since both the blue and orange dots are intermingled.

# %% [markdown]
# ## Part 4: Perform PCA Analysis for the Brain Observatory Data
#
# ### Generate a Scree Plot for the Brain Observatory
# Here we are generating a Scree plot to determine the number of components we should use for the PCA analysis.

# %%
# Create a PCA model
pca = PCA()
data_pca = pca.fit_transform(boc_norm)
#Here we plot out the data
plt.plot(pca.explained_variance_ratio_) # Plot the expected variance as a function of the PC
plt.axhline(.08,c='k',ls='--') # Plot a horizontal line at 1, the Kaiser criterion

plt.title('Scree Plot for the Brain Observatory Data')
plt.ylabel('Eigenvalue') 
plt.xlabel('Principal Component #')
plt.xlim(0,5)
plt.show()

# %% [markdown]
# ### Figure 7.
# Based off the elbow method for the Scree plot, we determined that we should include 2 components in our PCA analysis. We decided this by determining where our plot crosses the dotted line. We set the dotted line at 1, which is the Kaiser criterion, and the line crosses at 2.

# %% [markdown]
# ### Perform PCA Clustering Analysis on the Brain Observatory Data
# We will now conduct the PCA analysis on the Brain Observatory Normalized data, with 2 components.

# %%
#Create PCA model
pca = PCA(n_components = 2) 
#fit data to 2d model
boc_2D = pca.fit_transform(boc_norm) 
boc_2D

boc_subset['PC1'] = boc_2D[:, 0]
boc_subset['PC2'] = boc_2D[:, 1]

sns.lmplot("PC1", "PC2", hue='imaging_depth', data=boc_subset, fit_reg=False)
plt.title('PC1 vs. PC2 Clustering Analysis for the Brain Observatory Data')
plt.show()

# %% [markdown]
# ### Figure 8.
# Since much of the Brain Observatory data was removed when dropping the NaNs to prepare for the PCA analysis, the graph does not include many datapoints or display all of the layers in the cortex. Based off of the corresponding Cre-lines with the imaging depth, we can classify each layer represented by the imaging depth. The depth of 175 represents Layers 2/3, the depth of 275 and 350 represent Layer 4, and the depth of 375 represents Layer 5. Even without the dense clustering, we can still see that the data does not cluster into distinct clusters based off of layers.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# In our project, we first sought to compare the labelling of the Cre-lines in each cortical layer of the primary visual cortex by using the normalized depth metric of the Cell Types database and the measured depths reported in the Brain Observatory database. Both boxplots reveal that Ntsr1-Cre labels the deepest layer of cortex (Figure 1, 2). In Figure 1, Pvalb-IRES-Cre, Sst-IRES-Cre, Rorb-IRES2-Cre, and the Vip-IRES-Cre lines show more spread out expression. The Rbp4-Cre and Tlx3-Cre lines both show dense expression in the same layer and the Scnn1a-Tg3-Cre and Nr5a1-Cre lines both show expression in the same, more superficial layer (Figure 2). The imaging depths of each line was Ntsr1-Cre at 550, Cux2-CreERT2 at 225, Tlx3-Cre at 375, Nr51a-Cre at 350, Scnn1a-Cre at 350 and Rbp4-Cre at 385 (Figure 2).
#
#
# From the documentation of the Allen Brain Institute and the literature, we know Ntsr1-Cre labeled cells are expressed in Layer VI, Cux2-CreERT2 cells are located in Layer II/III/IV, Tlx3-Cre cells are found in Layer V pyramidal neurons, Nr5la-Cre neurons were locally expressed in Layer IV, Scnn1a-Cre expressed in Layer IV, and Rbp4-Cre labeled neurons were largely found in Layer V. Although our results align loosely with the layers defined in the Allen Brain Institute, the depths are comparatively shallow when matched with the depth ranges of the layers defined in the literature. This could be due to experimental procedures performed at the Allen Brain Institute since the calcium imaging with GcaMP often compresses the cortex. We also analyzed the correlation between the depths of each Cre-line of both databases. Our scatter plot and calculated Pearson’s r revealed a strong, positive correlation at .78, which was statistically significant with a p-value of .008. Therefore, the depth of expression between the shared Cre-lines are strongly correlated between the two databases.
#
#
# We then sought to determine if the data in both databases would cluster by cortical layer. To test this, we performed PCA clustering analysis on the electrophysiology data in the Cell Types database and the calcium imaging data from the Brain Observatory database. We first generated a Scree plot for the Cell Types data and determined our analysis would require four components (Figure 4). Four components is a relatively high number of components for PCA analysis, which indicates our data does not reduce into as many dimensions. Our clustering analysis did not generate any distinct clusters when we clustered based on layers (Figure 5). We found that the data points for Layer 4 tend to cluster closer together, so we grouped all of the layers besides Layer 4 together and performed another clustering analysis. This plot more clearly demonstrates how Layer 4 tends to cluster together (Figure 6). We hypothesize we see closer clustering of Layer 4, compared to other layers, because Layer 4 exists as the distinct, input layer. Layer 4 exhibits more distinct cell features as the input layer, so we saw these data points cluster closer together.
#
#
# We then performed the PCA cluster analysis on the Brain Observatory data, based off of the imaging depth data. We generated another Scree plot and found the analysis requires two components, so the Brain Observatory data reduces more than the Cell Types data (Figure 7). We then performed the PCA analysis, which did not reveal any distinct clustering based off of the layers (Figure 8). Our analysis was limited because the Brain Observatory database did not include many data points after filtering the data for missing data. This resulted in sparse clustering and not all of the layers were represented in the graph. Regardless, we still do not see distinct clustering into layers. Future studies could further study the electrophysiology features of Layer 4 cells to determine its distinct features. Other studies could also peform PCA analysis on each specific electrophysiology feature to determine if any features cluster by layer.

# %% [markdown]
# # Reflection

# %% [markdown]
# This project allowed us to work through code and problem solve with the help and guidance of Dr. J. It was helpful to have to generate, troubleshoot and plot all of the code from start to finish giving us a tangible application exercise to explore a topic of our choice. The process, while stressful, was quite rewarding in that we learned to work with a team to ensure the project’s success by utilizing the combined strengths of all members in a cohesive and fair way. It gave us an opportunity to pull something together from conceptualization and designing the experiment exposing us to the process of experiment revision and giving us an opportunity to develop a goal that was reasonable and interesting given the data we had access to within our area of interest. This application of technical skill, problem solving and teamwork was arguably one of the most engaging and interesting tasks included in this course as coding tends to be isolating, in accordance with the stereotypes, the collaboration was refreshing and reassuring as we dealt with the frustration of trying to get code to work and plots to be easily interpretable.
#
# One thing we believe could be improved is allowing more time for the groups to work on the projects. Ultimately, we believe the project would have been a bit more mangeable if we just had one overall project due at the end of the quarter. In place of the due date for the Cell Types project, there could be a checkin to keep everyone up to date with their projects. We also think having a lecture with a notebook that goes through how to access the data from each database would be really helpful. There were a lot of databases we could have worked with, but we really only learned how to use the Cell Types and Brain Observatory one.
